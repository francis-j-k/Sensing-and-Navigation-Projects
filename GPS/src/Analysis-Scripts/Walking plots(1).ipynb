# %%
import bagpy
from bagpy import bagreader
import pandas as pd
import seaborn as sea
import numpy as np
import matplotlib.pyplot as plt

# %%
b = bagreader('/home/francis/bagfiles/Data/walking.bag')
# Out:
# [INFO]  Data folder /home/francis/bagfiles/Data/walking already exists. Not creating.

# %%
b.topic_table
# Out:
#   Topics               Types  Message Count  Frequency
# 0   /gps  gps_driver/gps_msg           1704   1.000064

# %%
def data_csv(b):
    csvfiles = []
    for t in b.topics:
        data = b.message_by_topic(t)
        csvfiles.append(data)
        
    print(csvfiles[0])
    data = pd.read_csv(csvfiles[0])
    return data

# %%
csv_data = data_csv(b)
# Out:
# /home/francis/bagfiles/Data/walking/gps.csv

# %%
f = pd.read_csv("/home/francis/bagfiles/Data/walking/gps (copy).csv")

# %%
f
# Out:
#              Time  Header.seq  Header.stamp.secs  Header.stamp.nsecs  \
# 0    1.663962e+09           0              70989                   0
# 1    1.663962e+09           0              70990                   0
# 2    1.663962e+09           0              70991                   0
# 3    1.663962e+09           0              70992                   0
# 4    1.663962e+09           0              70993                   0
# ..            ...         ...                ...                 ...
# 617  1.663963e+09           0              71606                   0
# 618  1.663963e+09           0              71607                   0
# 619  1.663963e+09           0              71608                   0
# 620  1.663963e+09           0              71609                   0
# 621  1.663963e+09           0              71610                   0
#
#     Header.frame_id   Latitude  Longitude  Altitude    UTM_easting  \
# 0        GPS1_Frame  42.334330 -71.089430      17.6  327863.508946
# 1        GPS1_Frame  42.334325 -71.089418      17.7  327864.456496
# 2        GPS1_Frame  42.334318 -71.089405      18.0  327865.536813
# 3        GPS1_Frame  42.334315 -71.089392      18.0  327866.626224
# 4        GPS1_Frame  42.334312 -71.089378      18.1  327867.715635
# ..              ...        ...        ...       ...            ...
# 617      GPS1_Frame  42.333780 -71.086890      22.0  328071.275397
# 618      GPS1_Frame  42.333780 -71.086890      22.0  328071.275397
# 619      GPS1_Frame  42.333780 -71.086890      22.0  328071.275397
# 620      GPS1_Frame  42.333780 -71.086890      22.0  328071.275397
# 621      GPS1_Frame  42.333780 -71.086890      22.1  328071.275397
#
#      UTM_northing  Zone Letter  Header.stamp.secs.1  Offset_UTM_easting  \
# 0    4.689012e+06    19      T                 1082          863.508946
# 1    4.689011e+06    19      T                 1083          864.456496
# 2    4.689011e+06    19      T                 1084          865.536813
# 3    4.689010e+06    19      T                 1085          866.626224
# 4    4.689010e+06    19      T                 1086          867.715635
# ..            ...   ...    ...                  ...                 ...
# 617  4.688946e+06    19      T                 1699         1071.275397
# 618  4.688946e+06    19      T                 1700         1071.275397
# 619  4.688946e+06    19      T                 1701         1071.275397
# 620  4.688946e+06    19      T                 1702         1071.275397
# 621  4.688946e+06    19      T                 1703         1071.275397
#
#      Offset_UTM_northing
# 0             511.847662
# 1             511.268834
# 2             510.501561
# 3             510.104430
# 4             509.707299
# ..                   ...
# 617           445.635840
# 618           445.635840
# 619           445.635840
# 620           445.635840
# 621           445.635840
#
# [622 rows x 15 columns]

# %%
fig, a = bagpy.create_fig(1)
a[0].scatter(x='Header.stamp.secs.1', y='Altitude',data=f)
plt.title("Graph of Altitude vs Time")
plt.xlabel("Time is Seconds")
plt.ylabel("Altitude in meters")
plt.show()

# %%
fig, a = bagpy.create_fig(1)
a[0].scatter(x='Offset_UTM_easting', y='Offset_UTM_northing',data=df)
plt.title("Graph of UMT Northing vs UMT Easting")
plt.xlabel("Offset_UTM_easting")
plt.ylabel("Offset_UTM_northing")
plt.show()
