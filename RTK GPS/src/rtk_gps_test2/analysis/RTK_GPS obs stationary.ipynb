# %%
import bagpy
from bagpy import bagreader
import pandas as pd
import seaborn as sea
import numpy as np
import matplotlib.pyplot as plt

# %%
b = bagreader('/home/francis/catkin_ws/src/rtk_gps/Data/obs_stationary.bag')
# Out:
# [INFO]  Data folder /home/francis/catkin_ws/src/rtk_gps/Data/obs_stationary already exists. Not creating.

# %%
b.topic_table
# Out:
#   Topics                 Types  Message Count  Frequency
# 0  /gnss  gnss_driver/gnss_msg            597   1.000099

# %%
def data_csv(b):
    csvfiles = []
    for t in b.topics:
        data = b.message_by_topic(t)
        csvfiles.append(data)
        
    print(csvfiles[0])
    data = pd.read_csv(csvfiles[0])
    return data

# %%
csv_data = data_csv(b)
# Out:
# /home/francis/catkin_ws/src/rtk_gps/Data/obs_stationary/gnss.csv

# %%
f = pd.read_csv("/home/francis/catkin_ws/src/rtk_gps/Data/obs_stationary/gnss.csv")

# %%
f['UTM_easting_median'] = f['UTM_easting'] - f['UTM_easting'].median(axis=0)
f['UTM_northing_median'] = f['UTM_northing'] - f['UTM_northing'].median(axis=0)

# %%
f
# Out:
#              Time  Header.seq  Header.stamp.secs  Header.stamp.nsecs  \
# 0    1.665619e+09           0         1665633061                   0
# 1    1.665619e+09           0         1665633062                   0
# 2    1.665619e+09           0         1665633063                   0
# 3    1.665619e+09           0         1665633064                   0
# 4    1.665619e+09           0         1665633065                   0
# ..            ...         ...                ...                 ...
# 592  1.665619e+09           0         1665547253                   0
# 593  1.665619e+09           0         1665547254                   0
# 594  1.665619e+09           0         1665547255                   0
# 595  1.665619e+09           0         1665547256                   0
# 596  1.665619e+09           0         1665547257                   0
#
#     Header.frame_id   Latitude  Longitude  Altitude    UTM_easting  \
# 0       GNSS1_Frame  42.337434 -71.086497       9.4  328113.623840
# 1       GNSS1_Frame  42.337434 -71.086497       9.4  328113.623840
# 2       GNSS1_Frame  42.337434 -71.086497       9.4  328113.637571
# 3       GNSS1_Frame  42.337434 -71.086497       9.4  328113.637571
# 4       GNSS1_Frame  42.337434 -71.086497       9.4  328113.623840
# ..              ...        ...        ...       ...            ...
# 592     GNSS1_Frame  42.337434 -71.086497       9.4  328113.636662
# 593     GNSS1_Frame  42.337434 -71.086497       9.4  328113.636662
# 594     GNSS1_Frame  42.337434 -71.086497       9.4  328113.636662
# 595     GNSS1_Frame  42.337434 -71.086497       9.4  328113.636662
# 596     GNSS1_Frame  42.337434 -71.086497       9.4  328113.636662
#
#      UTM_northing  Zone Letter  quality  satellites  hdop  UTM_easting_median  \
# 0    4.689351e+06    19      T        4          12  1.00           -0.027007
# 1    4.689351e+06    19      T        4          12  1.00           -0.027007
# 2    4.689351e+06    19      T        4          12  1.00           -0.013277
# 3    4.689351e+06    19      T        4          12  1.00           -0.013277
# 4    4.689351e+06    19      T        4          12  1.00           -0.027007
# ..            ...   ...    ...      ...         ...   ...                 ...
# 592  4.689351e+06    19      T        4          12  0.76           -0.014185
# 593  4.689351e+06    19      T        4          12  0.77           -0.014185
# 594  4.689351e+06    19      T        4          12  0.77           -0.014185
# 595  4.689351e+06    19      T        4          12  0.90           -0.014185
# 596  4.689351e+06    19      T        4          12  0.92           -0.014185
#
#      UTM_northing_median
# 0               0.019181
# 1               0.019181
# 2               0.018844
# 3               0.018844
# 4               0.019181
# ..                   ...
# 592            -0.018170
# 593            -0.018170
# 594            -0.018170
# 595            -0.018170
# 596            -0.018170
#
# [597 rows x 17 columns]

# %%
f['quality']. value_counts()
# Out:
# 4    595
# 5      1
# 2      1
# Name: quality, dtype: int64

# %%
fig, a = bagpy.create_fig(1)
scatter = a[0].scatter(x='UTM_easting_median', y='UTM_northing_median', data=f, c='quality')

m=f['UTM_easting_median'].median()
n=f['UTM_northing_median'].median()
plt.title("UTM Northing vs UTM Easting")
plt.xlabel("UTM_easting(meter)")
plt.ylabel("UTM_northing(meter)")
legend1 =a[0].legend(*scatter.legend_elements(), loc="upper right", title="Quality")
a[0].axis("equal")
a[0].add_artist(legend1)

plt.show()

# %%
fig, a = bagpy.create_fig(1)
scatter = a[0].scatter(x='UTM_easting_median', y='UTM_northing_median', data=f, c='quality')
#y=f['UTM_easting_median'][0:120]
#x=f['UTM_northing_median'][0:120]
m=f['UTM_easting_median'].median()
n=f['UTM_northing_median'].median()
#rms = np.sqrt((()*(x-m))/f.count())
#sqrt(())
sigx=f['UTM_easting_median'].std()
sigy=f['UTM_northing_median'].std()
CEP=0.62*sigx + 0.56*sigy
DRMS=2*np.sqrt((sigx*sigx)+(sigy*sigy))
circle = plt.Circle((m,n),DRMS,color='blue',alpha=0.1)
circle1 = plt.Circle((m,n),CEP,color='forestgreen',alpha=0.1)
#m,b = np.polyfit(x,y,1)data:image/png;base64,...
#plt.plot(x,(m*x) + b,color="black")
plt.title("UTM Northing vs UTM Easting")
plt.xlabel("UTM_easting(meter)")
plt.ylabel("UTM_northing(meter)")
legend1 =a[0].legend(*scatter.legend_elements(), loc="upper right", title="Quality")
a[0].axis("equal")
a[0].add_artist(legend1)
a[0].add_patch(circle)
a[0].add_patch(circle1)
plt.show()

# %%
fig, a = bagpy.create_fig(1)
scatter = a[0].scatter(x='UTM_easting_median', y='UTM_northing_median', data=f, c='quality')
#y=f['UTM_easting_median'][0:120]
#x=f['UTM_northing_median'][0:120]
m=f['UTM_easting_median'].median()
n=f['UTM_northing_median'].median()
#rms = np.sqrt((()*(x-m))/f.count())
#sqrt(())
sigx=f['UTM_easting_median'].std()
sigy=f['UTM_northing_median'].std()
CEP=0.62*sigx + 0.56*sigy
DRMS=2*np.sqrt((sigx*sigx)+(sigy*sigy))
print(CEP)
print(DRMS)
# Out:
# 0.02086074318416295
# 0.05013835208322138
